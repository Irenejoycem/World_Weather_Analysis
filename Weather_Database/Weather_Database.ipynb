# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)

# %%
len(cities)
# Out:
# 611

# %%
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
from datetime import datetime
import requests

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    city_url = url + "&q=" + city.replace(" ","+")
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    try:
        city_weather = requests.get(city_url).json()
    
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather["weather"][0]["description"]
        
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description" : current_description})
        print(city_weather)
        
    except KeyError:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# {'coord': {'lon': 172.79, 'lat': 3.07}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 82.04, 'feels_like': 84.94, 'temp_min': 82.04, 'temp_max': 82.04, 'pressure': 1006, 'humidity': 75, 'sea_level': 1006, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 11.52, 'deg': 143}, 'clouds': {'all': 72}, 'dt': 1604024115, 'sys': {'country': 'KI', 'sunrise': 1603995120, 'sunset': 1604038370}, 'timezone': 43200, 'id': 2110227, 'name': 'Butaritari', 'cod': 200}
# Processing Record 2 of Set 1 | dudinka
# {'coord': {'lon': 86.18, 'lat': 69.41}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 8.24, 'feels_like': -4.76, 'temp_min': 8.24, 'temp_max': 8.24, 'pressure': 1019, 'humidity': 92, 'sea_level': 1019, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 12.44, 'deg': 162}, 'clouds': {'all': 90}, 'dt': 1604024696, 'sys': {'country': 'RU', 'sunrise': 1604025019, 'sunset': 1604050043}, 'timezone': 25200, 'id': 1507116, 'name': 'Dudinka', 'cod': 200}
# Processing Record 3 of Set 1 | luderitz
# {'coord': {'lon': 15.16, 'lat': -26.65}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 56.39, 'feels_like': 40.33, 'temp_min': 56.39, 'temp_max': 56.39, 'pressure': 1018, 'humidity': 74, 'sea_level': 1018, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 27.83, 'deg': 159}, 'clouds': {'all': 0}, 'dt': 1604024379, 'sys': {'country': 'NA', 'sunrise': 1604031029, 'sunset': 1604078121}, 'timezone': 7200, 'id': 3355672, 'name': 'Lüderitz', 'cod': 200}
# Processing Record 4 of Set 1 | upernavik
# {'coord': {'lon': -56.15, 'lat': 72.79}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 22.91, 'feels_like': 15.3, 'temp_min': 22.91, 'temp_max': 22.91, 'pressure': 997, 'humidity': 97, 'sea_level': 997, 'grnd_level': 997}, 'visibility': 514, 'wind': {'speed': 5.03, 'deg': 112}, 'snow': {'1h': 0.12}, 'clouds': {'all': 100}, 'dt': 1604024335, 'sys': {'country': 'GL', 'sunrise': 1603975019, 'sunset': 1603995564}, 'timezone': -10800, 'id': 3418910, 'name': 'Upernavik', 'cod': 200}
# Processing Record 5 of Set 1 | rikitea
# {'coord': {'lon': -134.97, 'lat': -23.12}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 75.56, 'feels_like': 77.63, 'temp_min': 75.56, 'temp_max': 75.56, 'pressure': 1017, 'humidity': 73, 'sea_level': 1017, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 6.73, 'deg': 321}, 'clouds': {'all': 100}, 'dt': 1604024270, 'sys': {'country': 'PF', 'sunrise': 1603980947, 'sunset': 1604027468}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# Processing Record 6 of Set 1 | atuona
# {'coord': {'lon': -139.03, 'lat': -9.8}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 78.15, 'feels_like': 76.51, 'temp_min': 78.15, 'temp_max': 78.15, 'pressure': 1012, 'humidity': 73, 'sea_level': 1012, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 15.39, 'deg': 95}, 'rain': {'1h': 0.14}, 'clouds': {'all': 86}, 'dt': 1604024115, 'sys': {'country': 'PF', 'sunrise': 1603982793, 'sunset': 1604027571}, 'timezone': -34200, 'id': 4020109, 'name': 'Atuona', 'cod': 200}
# Processing Record 7 of Set 1 | sarkand
# {'coord': {'lon': 79.92, 'lat': 45.41}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 34.99, 'feels_like': 28.96, 'temp_min': 34.99, 'temp_max': 34.99, 'pressure': 1040, 'humidity': 69, 'sea_level': 1040, 'grnd_level': 945}, 'visibility': 10000, 'wind': {'speed': 2.93, 'deg': 147}, 'clouds': {'all': 42}, 'dt': 1604024697, 'sys': {'country': 'KZ', 'sunrise': 1604020610, 'sunset': 1604057457}, 'timezone': 21600, 'id': 1519691, 'name': 'Sarkand', 'cod': 200}
# Processing Record 8 of Set 1 | vaitape
# {'coord': {'lon': -151.75, 'lat': -16.52}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 81.1, 'feels_like': 84.87, 'temp_min': 81.1, 'temp_max': 81.1, 'pressure': 1012, 'humidity': 77, 'sea_level': 1012, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 9.89, 'deg': 38}, 'clouds': {'all': 0}, 'dt': 1604024697, 'sys': {'country': 'PF', 'sunrise': 1603985422, 'sunset': 1604031047}, 'timezone': -36000, 'id': 4033077, 'name': 'Vaitape', 'cod': 200}
# Processing Record 9 of Set 1 | tasiilaq
# {'coord': {'lon': -37.64, 'lat': 65.61}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 35.6, 'feels_like': 17.47, 'temp_min': 35.6, 'temp_max': 35.6, 'pressure': 989, 'humidity': 64}, 'visibility': 390, 'wind': {'speed': 24.16, 'deg': 80, 'gust': 41.38}, 'clouds': {'all': 100}, 'dt': 1604024278, 'sys': {'type': 1, 'id': 81, 'country': 'GL', 'sunrise': 1603966431, 'sunset': 1603995267}, 'timezone': -10800, 'id': 3424607, 'name': 'Tasiilaq', 'cod': 200}
# Processing Record 10 of Set 1 | mount gambier
# {'coord': {'lon': 140.77, 'lat': -37.83}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 62.6, 'feels_like': 55.45, 'temp_min': 62.6, 'temp_max': 62.6, 'pressure': 1013, 'humidity': 63}, 'visibility': 10000, 'wind': {'speed': 12.75, 'deg': 170}, 'clouds': {'all': 75}, 'dt': 1604024365, 'sys': {'type': 1, 'id': 9560, 'country': 'AU', 'sunrise': 1603999925, 'sunset': 1604048934}, 'timezone': 37800, 'id': 2156643, 'name': 'Mount Gambier', 'cod': 200}
# Processing Record 11 of Set 1 | mutsu
# {'coord': {'lon': 141.22, 'lat': 41.29}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 51.8, 'feels_like': 43, 'temp_min': 51.8, 'temp_max': 51.8, 'pressure': 1016, 'humidity': 62}, 'visibility': 10000, 'wind': {'speed': 11.41, 'deg': 270}, 'clouds': {'all': 75}, 'dt': 1604024698, 'sys': {'type': 1, 'id': 8050, 'country': 'JP', 'sunrise': 1604005432, 'sunset': 1604043211}, 'timezone': 32400, 'id': 2127878, 'name': 'Mutsu', 'cod': 200}
# Processing Record 12 of Set 1 | sarangani
# {'coord': {'lon': 125.46, 'lat': 5.4}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 83.75, 'feels_like': 87.3, 'temp_min': 83.75, 'temp_max': 83.75, 'pressure': 1009, 'humidity': 77, 'sea_level': 1009, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 12.86, 'deg': 265}, 'clouds': {'all': 57}, 'dt': 1604024698, 'sys': {'country': 'PH', 'sunrise': 1604006617, 'sunset': 1604049590}, 'timezone': 28800, 'id': 1687186, 'name': 'Sarangani', 'cod': 200}
# Processing Record 13 of Set 1 | yellowknife
# {'coord': {'lon': -114.35, 'lat': 62.46}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 14.72, 'feels_like': 7.16, 'temp_min': 14, 'temp_max': 16, 'pressure': 1019, 'humidity': 94, 'sea_level': 1019, 'grnd_level': 999}, 'visibility': 10000, 'wind': {'speed': 3.58, 'deg': 271}, 'clouds': {'all': 80}, 'dt': 1604024204, 'sys': {'type': 3, 'id': 19346, 'country': 'CA', 'sunrise': 1603983853, 'sunset': 1604014665}, 'timezone': -21600, 'id': 6185377, 'name': 'Yellowknife', 'cod': 200}
# Processing Record 14 of Set 1 | punta arenas
# {'coord': {'lon': -70.92, 'lat': -53.15}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 44.6, 'feels_like': 38.59, 'temp_min': 44.6, 'temp_max': 44.6, 'pressure': 1014, 'humidity': 75}, 'visibility': 10000, 'wind': {'speed': 5.82, 'deg': 310}, 'clouds': {'all': 75}, 'dt': 1604024298, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1603962330, 'sunset': 1604015342}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# Processing Record 15 of Set 1 | puerto ayora
# {'coord': {'lon': -90.35, 'lat': -0.74}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 68, 'feels_like': 72.27, 'temp_min': 68, 'temp_max': 68, 'pressure': 1013, 'humidity': 95}, 'visibility': 10000, 'wind': {'speed': 3, 'deg': 174, 'gust': 10}, 'clouds': {'all': 100}, 'dt': 1604024287, 'sys': {'type': 3, 'id': 2005652, 'country': 'EC', 'sunrise': 1603971651, 'sunset': 1604015348}, 'timezone': -21600, 'id': 3652764, 'name': 'Puerto Ayora', 'cod': 200}
# Processing Record 16 of Set 1 | yar-sale
# {'coord': {'lon': 70.83, 'lat': 66.83}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 17.01, 'feels_like': 6.94, 'temp_min': 17.01, 'temp_max': 17.01, 'pressure': 1010, 'humidity': 97, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 2265, 'wind': {'speed': 8.41, 'deg': 184}, 'clouds': {'all': 100}, 'dt': 1604024574, 'sys': {'country': 'RU', 'sunrise': 1604027438, 'sunset': 1604054991}, 'timezone': 18000, 'id': 1486321, 'name': 'Yar-Sale', 'cod': 200}
# Processing Record 17 of Set 1 | bluff
# {'coord': {'lon': 168.33, 'lat': -46.6}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 61, 'feels_like': 62.55, 'temp_min': 61, 'temp_max': 61, 'pressure': 1009, 'humidity': 91}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 182, 'gust': 4}, 'rain': {'1h': 0.15}, 'clouds': {'all': 100}, 'dt': 1604024299, 'sys': {'type': 3, 'id': 2008959, 'country': 'NZ', 'sunrise': 1603992299, 'sunset': 1604043332}, 'timezone': 46800, 'id': 2206939, 'name': 'Bluff', 'cod': 200}
# Processing Record 18 of Set 1 | mataura
# {'coord': {'lon': 168.86, 'lat': -46.19}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 61, 'feels_like': 62.55, 'temp_min': 61, 'temp_max': 61, 'pressure': 1009, 'humidity': 91}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 182, 'gust': 4}, 'clouds': {'all': 100}, 'dt': 1604024269, 'sys': {'type': 3, 'id': 2008959, 'country': 'NZ', 'sunrise': 1603992227, 'sunset': 1604043149}, 'timezone': 46800, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# Processing Record 19 of Set 1 | port elizabeth
# {'coord': {'lon': 25.57, 'lat': -33.92}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 55.4, 'feels_like': 49.69, 'temp_min': 55.4, 'temp_max': 55.4, 'pressure': 1025, 'humidity': 82}, 'visibility': 10000, 'wind': {'speed': 10.29, 'deg': 260}, 'clouds': {'all': 0}, 'dt': 1604024271, 'sys': {'type': 1, 'id': 1973, 'country': 'ZA', 'sunrise': 1604027926, 'sunset': 1604076228}, 'timezone': 7200, 'id': 964420, 'name': 'Port Elizabeth', 'cod': 200}
# Processing Record 20 of Set 1 | bud
# {'coord': {'lon': -86.18, 'lat': 39.45}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 44.51, 'feels_like': 37.29, 'temp_min': 44.01, 'temp_max': 45, 'pressure': 1013, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 9.17, 'deg': 360}, 'clouds': {'all': 90}, 'dt': 1604024459, 'sys': {'type': 1, 'id': 4345, 'country': 'US', 'sunrise': 1603973401, 'sunset': 1604011596}, 'timezone': -14400, 'id': 4255151, 'name': 'Bud', 'cod': 200}
# Processing Record 21 of Set 1 | vysokopillya
# {'coord': {'lon': 33.53, 'lat': 47.49}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 48.11, 'feels_like': 44.94, 'temp_min': 48, 'temp_max': 48.2, 'pressure': 1013, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 3.33, 'deg': 311}, 'clouds': {'all': 40}, 'dt': 1604024700, 'sys': {'type': 1, 'id': 8904, 'country': 'UA', 'sunrise': 1604032010, 'sunset': 1604068323}, 'timezone': 7200, 'id': 688689, 'name': 'Vysokopillya', 'cod': 200}
# Processing Record 22 of Set 1 | kavaratti
# {'coord': {'lon': 72.64, 'lat': 10.57}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 82.87, 'feels_like': 87.19, 'temp_min': 82.87, 'temp_max': 82.87, 'pressure': 1011, 'humidity': 68, 'sea_level': 1011, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 6.98, 'deg': 348}, 'clouds': {'all': 0}, 'dt': 1604024700, 'sys': {'country': 'IN', 'sunrise': 1604019605, 'sunset': 1604061956}, 'timezone': 19800, 'id': 1267390, 'name': 'Kavaratti', 'cod': 200}
# Processing Record 23 of Set 1 | natal
# {'coord': {'lon': -35.21, 'lat': -5.79}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 76.19, 'feels_like': 78.06, 'temp_min': 73.4, 'temp_max': 78.8, 'pressure': 1012, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 9.17, 'deg': 110}, 'clouds': {'all': 40}, 'dt': 1604024700, 'sys': {'type': 1, 'id': 8417, 'country': 'BR', 'sunrise': 1603958122, 'sunset': 1604002410}, 'timezone': -10800, 'id': 3394023, 'name': 'Natal', 'cod': 200}
# Processing Record 24 of Set 1 | talnakh
# {'coord': {'lon': 88.4, 'lat': 69.49}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 4.08, 'feels_like': -7.35, 'temp_min': 4.08, 'temp_max': 4.08, 'pressure': 1020, 'humidity': 87, 'sea_level': 1020, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 9.19, 'deg': 123}, 'clouds': {'all': 65}, 'dt': 1604024318, 'sys': {'country': 'RU', 'sunrise': 1604024530, 'sunset': 1604049466}, 'timezone': 25200, 'id': 1490256, 'name': 'Talnakh', 'cod': 200}
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | geraldton
# {'coord': {'lon': 114.6, 'lat': -28.77}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 93.2, 'feels_like': 90.28, 'temp_min': 93.2, 'temp_max': 93.2, 'pressure': 1012, 'humidity': 28}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 10}, 'clouds': {'all': 0}, 'dt': 1604024376, 'sys': {'type': 1, 'id': 9522, 'country': 'AU', 'sunrise': 1604007010, 'sunset': 1604054410}, 'timezone': 28800, 'id': 2070998, 'name': 'Geraldton', 'cod': 200}
# Processing Record 27 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 1 | mangan
# {'coord': {'lon': 88.53, 'lat': 27.52}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 74.77, 'feels_like': 68.77, 'temp_min': 74.77, 'temp_max': 74.77, 'pressure': 1021, 'humidity': 21, 'sea_level': 1021, 'grnd_level': 922}, 'visibility': 10000, 'wind': {'speed': 4.36, 'deg': 359}, 'clouds': {'all': 9}, 'dt': 1604024701, 'sys': {'country': 'IN', 'sunrise': 1604016905, 'sunset': 1604057029}, 'timezone': 19800, 'id': 1263776, 'name': 'Mangan', 'cod': 200}
# Processing Record 29 of Set 1 | cape town
# {'coord': {'lon': 18.42, 'lat': -33.93}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 48.88, 'feels_like': 44.28, 'temp_min': 46.4, 'temp_max': 51.01, 'pressure': 1026, 'humidity': 75}, 'visibility': 10000, 'wind': {'speed': 4.7, 'deg': 100}, 'clouds': {'all': 0}, 'dt': 1604024206, 'sys': {'type': 1, 'id': 1899, 'country': 'ZA', 'sunrise': 1604029639, 'sunset': 1604077946}, 'timezone': 7200, 'id': 3369157, 'name': 'Cape Town', 'cod': 200}
# Processing Record 30 of Set 1 | balykshi
# {'coord': {'lon': 51.87, 'lat': 47.07}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 39.2, 'feels_like': 24.82, 'temp_min': 39.2, 'temp_max': 39.2, 'pressure': 1025, 'humidity': 60}, 'visibility': 10000, 'wind': {'speed': 17.9, 'deg': 120}, 'clouds': {'all': 0}, 'dt': 1604024702, 'sys': {'type': 1, 'id': 8836, 'country': 'KZ', 'sunrise': 1604027551, 'sunset': 1604063979}, 'timezone': 18000, 'id': 610445, 'name': 'Balyqshy', 'cod': 200}
# Processing Record 31 of Set 1 | nikolskoye
# {'coord': {'lon': 30.79, 'lat': 59.7}, 'weather': [{'id': 521, 'main': 'Rain', 'description': 'shower rain', 'icon': '09n'}, {'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 49.66, 'feels_like': 46.62, 'temp_min': 48.99, 'temp_max': 50, 'pressure': 1010, 'humidity': 93}, 'visibility': 1100, 'wind': {'speed': 4.47, 'deg': 270}, 'rain': {'1h': 0.3}, 'clouds': {'all': 90}, 'dt': 1604024300, 'sys': {'type': 1, 'id': 8926, 'country': 'RU', 'sunrise': 1604034792, 'sunset': 1604066856}, 'timezone': 10800, 'id': 546105, 'name': 'Nikolskoye', 'cod': 200}
# Processing Record 32 of Set 1 | srandakan
# {'coord': {'lon': 110.25, 'lat': -7.94}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 86.5, 'feels_like': 92.23, 'temp_min': 86.5, 'temp_max': 86.5, 'pressure': 1012, 'humidity': 63, 'sea_level': 1012, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 5.59, 'deg': 134}, 'clouds': {'all': 0}, 'dt': 1604024702, 'sys': {'country': 'ID', 'sunrise': 1604009475, 'sunset': 1604054034}, 'timezone': 25200, 'id': 1626493, 'name': 'Srandakan', 'cod': 200}
# Processing Record 33 of Set 1 | qaanaaq
# {'coord': {'lon': -69.36, 'lat': 77.48}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 4.96, 'feels_like': -4.97, 'temp_min': 4.96, 'temp_max': 4.96, 'pressure': 999, 'humidity': 71, 'sea_level': 999, 'grnd_level': 999}, 'visibility': 10000, 'wind': {'speed': 6.29, 'deg': 46}, 'clouds': {'all': 5}, 'dt': 1604024115, 'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0}, 'timezone': -10800, 'id': 3831208, 'name': 'Qaanaaq', 'cod': 200}
# Processing Record 34 of Set 1 | khatanga
# {'coord': {'lon': 102.5, 'lat': 71.97}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 0.95, 'feels_like': -12.06, 'temp_min': 0.95, 'temp_max': 0.95, 'pressure': 1025, 'humidity': 85, 'sea_level': 1025, 'grnd_level': 1022}, 'visibility': 10000, 'wind': {'speed': 11.74, 'deg': 170}, 'clouds': {'all': 0}, 'dt': 1604024325, 'sys': {'country': 'RU', 'sunrise': 1604022839, 'sunset': 1604044390}, 'timezone': 25200, 'id': 2022572, 'name': 'Khatanga', 'cod': 200}
# Processing Record 35 of Set 1 | charters towers
# {'coord': {'lon': 146.27, 'lat': -20.1}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 90.84, 'feels_like': 83.37, 'temp_min': 90.84, 'temp_max': 90.84, 'pressure': 1010, 'humidity': 14, 'sea_level': 1010, 'grnd_level': 976}, 'visibility': 10000, 'wind': {'speed': 7.76, 'deg': 328}, 'clouds': {'all': 0}, 'dt': 1604024703, 'sys': {'country': 'AU', 'sunrise': 1604000053, 'sunset': 1604046166}, 'timezone': 36000, 'id': 2171722, 'name': 'Charters Towers', 'cod': 200}
# Processing Record 36 of Set 1 | nome
# {'coord': {'lon': -165.41, 'lat': 64.5}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 26.29, 'feels_like': 18.93, 'temp_min': 26.01, 'temp_max': 26.6, 'pressure': 1017, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 3.76, 'deg': 331}, 'clouds': {'all': 1}, 'dt': 1604024356, 'sys': {'type': 1, 'id': 7770, 'country': 'US', 'sunrise': 1603996773, 'sunset': 1604026254}, 'timezone': -28800, 'id': 5870133, 'name': 'Nome', 'cod': 200}
# Processing Record 37 of Set 1 | east london
# {'coord': {'lon': 27.91, 'lat': -33.02}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 62.28, 'feels_like': 54, 'temp_min': 62.28, 'temp_max': 62.28, 'pressure': 1025, 'humidity': 73, 'sea_level': 1025, 'grnd_level': 1021}, 'visibility': 10000, 'wind': {'speed': 16.62, 'deg': 224}, 'clouds': {'all': 100}, 'dt': 1604024270, 'sys': {'country': 'ZA', 'sunrise': 1604027445, 'sunset': 1604075585}, 'timezone': 7200, 'id': 1006984, 'name': 'East London', 'cod': 200}
# Processing Record 38 of Set 1 | kulhudhuffushi
# {'coord': {'lon': 73.07, 'lat': 6.62}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 82.31, 'feels_like': 87.46, 'temp_min': 82.31, 'temp_max': 82.31, 'pressure': 1011, 'humidity': 71, 'sea_level': 1011, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 6.22, 'deg': 336}, 'clouds': {'all': 27}, 'dt': 1604024703, 'sys': {'country': 'MV', 'sunrise': 1604019264, 'sunset': 1604062090}, 'timezone': 18000, 'id': 1337613, 'name': 'Kulhudhuffushi', 'cod': 200}
# Processing Record 39 of Set 1 | castro
# {'coord': {'lon': -50.01, 'lat': -24.79}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 60.24, 'feels_like': 60.26, 'temp_min': 60.24, 'temp_max': 60.24, 'pressure': 1015, 'humidity': 96, 'sea_level': 1015, 'grnd_level': 903}, 'visibility': 10000, 'wind': {'speed': 5.19, 'deg': 131}, 'rain': {'1h': 0.486}, 'clouds': {'all': 100}, 'dt': 1604024275, 'sys': {'country': 'BR', 'sunrise': 1603960445, 'sunset': 1604007191}, 'timezone': -10800, 'id': 3466704, 'name': 'Castro', 'cod': 200}
# Processing Record 40 of Set 1 | mahebourg
# {'coord': {'lon': 57.7, 'lat': -20.41}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 66.99, 'feels_like': 65.12, 'temp_min': 66.99, 'temp_max': 66.99, 'pressure': 1021, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 5.99, 'deg': 137, 'gust': 11.99}, 'rain': {'1h': 0.12}, 'clouds': {'all': 17}, 'dt': 1604024292, 'sys': {'type': 3, 'id': 2002134, 'country': 'MU', 'sunrise': 1604021280, 'sunset': 1604067452}, 'timezone': 14400, 'id': 934322, 'name': 'Mahébourg', 'cod': 200}
# Processing Record 41 of Set 1 | petauke
# {'coord': {'lon': 31.33, 'lat': -14.24}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 69.03, 'feels_like': 66.42, 'temp_min': 69.03, 'temp_max': 69.03, 'pressure': 1013, 'humidity': 52, 'sea_level': 1013, 'grnd_level': 901}, 'visibility': 10000, 'wind': {'speed': 5.1, 'deg': 87}, 'clouds': {'all': 0}, 'dt': 1604024286, 'sys': {'country': 'ZM', 'sunrise': 1604028018, 'sunset': 1604073371}, 'timezone': 7200, 'id': 899825, 'name': 'Petauke', 'cod': 200}
# Processing Record 42 of Set 1 | vaini
# {'coord': {'lon': -175.2, 'lat': -21.2}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 77, 'feels_like': 76.82, 'temp_min': 77, 'temp_max': 77, 'pressure': 1017, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 9.17, 'deg': 120}, 'clouds': {'all': 20}, 'dt': 1604024269, 'sys': {'type': 1, 'id': 7285, 'country': 'TO', 'sunrise': 1604077098, 'sunset': 1604123423}, 'timezone': 46800, 'id': 4032243, 'name': 'Vaini', 'cod': 200}
# Processing Record 43 of Set 1 | bakchar
# {'coord': {'lon': 82.07, 'lat': 57.02}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 28.26, 'feels_like': 21.69, 'temp_min': 28.26, 'temp_max': 28.26, 'pressure': 1016, 'humidity': 99, 'sea_level': 1016, 'grnd_level': 1002}, 'visibility': 10000, 'wind': {'speed': 4.36, 'deg': 273}, 'clouds': {'all': 85}, 'dt': 1604024704, 'sys': {'country': 'RU', 'sunrise': 1604021873, 'sunset': 1604055162}, 'timezone': 25200, 'id': 1511057, 'name': 'Bakchar', 'cod': 200}
# Processing Record 44 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 1 | kaitangata
# {'coord': {'lon': 169.85, 'lat': -46.28}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 62.01, 'feels_like': 63.59, 'temp_min': 62.01, 'temp_max': 62.01, 'pressure': 1007, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 90, 'gust': 1.99}, 'clouds': {'all': 100}, 'dt': 1604024267, 'sys': {'type': 3, 'id': 2000217, 'country': 'NZ', 'sunrise': 1603991978, 'sunset': 1604042923}, 'timezone': 46800, 'id': 2208248, 'name': 'Kaitangata', 'cod': 200}
# Processing Record 46 of Set 1 | bengkulu
# {'coord': {'lon': 102.27, 'lat': -3.8}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 76.6, 'feels_like': 83.98, 'temp_min': 76.6, 'temp_max': 76.6, 'pressure': 1012, 'humidity': 87, 'sea_level': 1012, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 2.71, 'deg': 20}, 'rain': {'1h': 1.3324}, 'clouds': {'all': 99}, 'dt': 1604024352, 'sys': {'country': 'ID', 'sunrise': 1604011639, 'sunset': 1604055700}, 'timezone': 25200, 'id': 1649150, 'name': 'Bengkulu', 'cod': 200}
# Processing Record 47 of Set 1 | fortuna
# {'coord': {'lon': -124.16, 'lat': 40.6}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 52.12, 'feels_like': 52.11, 'temp_min': 50, 'temp_max': 54, 'pressure': 1018, 'humidity': 100}, 'visibility': 10000, 'wind': {'speed': 1.23, 'deg': 122}, 'clouds': {'all': 1}, 'dt': 1604023982, 'sys': {'type': 1, 'id': 4127, 'country': 'US', 'sunrise': 1603982635, 'sunset': 1604020592}, 'timezone': -25200, 'id': 5563839, 'name': 'Fortuna', 'cod': 200}
# Processing Record 48 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 1 | udachnyy
# {'coord': {'lon': 112.4, 'lat': 66.42}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': -8.28, 'feels_like': -15.52, 'temp_min': -8.28, 'temp_max': -8.28, 'pressure': 1032, 'humidity': 90, 'sea_level': 1032, 'grnd_level': 993}, 'visibility': 6629, 'wind': {'speed': 1.03, 'deg': 83}, 'clouds': {'all': 63}, 'dt': 1604024647, 'sys': {'country': 'RU', 'sunrise': 1604017263, 'sunset': 1604045213}, 'timezone': 32400, 'id': 2014624, 'name': 'Udachny', 'cod': 200}
# Processing Record 50 of Set 1 | petropavlovsk-kamchatskiy
# {'coord': {'lon': 158.65, 'lat': 53.05}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 46.4, 'feels_like': 41.83, 'temp_min': 46.4, 'temp_max': 46.4, 'pressure': 1024, 'humidity': 61}, 'visibility': 10000, 'wind': {'speed': 2.24, 'deg': 0}, 'clouds': {'all': 75}, 'dt': 1604024422, 'sys': {'type': 1, 'id': 8887, 'country': 'RU', 'sunrise': 1604002747, 'sunset': 1604037530}, 'timezone': 43200, 'id': 2122104, 'name': 'Petropavlovsk-Kamchatskiy', 'cod': 200}
# Processing Record 1 of Set 2 | sukhumi
# {'coord': {'lon': 41.02, 'lat': 43}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 64.65, 'feels_like': 61.88, 'temp_min': 64.65, 'temp_max': 64.65, 'pressure': 1016, 'humidity': 58, 'sea_level': 1016, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 4.83, 'deg': 56}, 'rain': {'1h': 0.205}, 'clouds': {'all': 100}, 'dt': 1604024706, 'sys': {'country': 'GE', 'sunrise': 1604029681, 'sunset': 1604067057}, 'timezone': 14400, 'id': 611847, 'name': 'Sukhumi', 'cod': 200}
# Processing Record 2 of Set 2 | kapaa
# {'coord': {'lon': -159.32, 'lat': 22.08}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.42, 'feels_like': 78.96, 'temp_min': 79, 'temp_max': 82.4, 'pressure': 1009, 'humidity': 58}, 'visibility': 10000, 'wind': {'speed': 11.41, 'deg': 60}, 'clouds': {'all': 1}, 'dt': 1604024278, 'sys': {'type': 1, 'id': 7873, 'country': 'US', 'sunrise': 1603989596, 'sunset': 1604030507}, 'timezone': -36000, 'id': 5848280, 'name': 'Kapaa', 'cod': 200}
# Processing Record 3 of Set 2 | boa vista
# {'coord': {'lon': -60.67, 'lat': 2.82}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 84.2, 'feels_like': 90.01, 'temp_min': 84.2, 'temp_max': 84.2, 'pressure': 1009, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 4.7, 'deg': 160}, 'rain': {'1h': 1}, 'clouds': {'all': 20}, 'dt': 1604024706, 'sys': {'type': 1, 'id': 8340, 'country': 'BR', 'sunrise': 1603964736, 'sunset': 1604008017}, 'timezone': -14400, 'id': 3664980, 'name': 'Boa Vista', 'cod': 200}
# Processing Record 4 of Set 2 | hermanus
# {'coord': {'lon': 19.23, 'lat': -34.42}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 46, 'feels_like': 43.09, 'temp_min': 46, 'temp_max': 46, 'pressure': 1028, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 2.08, 'deg': 205}, 'clouds': {'all': 42}, 'dt': 1604024311, 'sys': {'type': 3, 'id': 2006131, 'country': 'ZA', 'sunrise': 1604029400, 'sunset': 1604077796}, 'timezone': 7200, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# Processing Record 5 of Set 2 | enid
# {'coord': {'lon': -97.88, 'lat': 36.4}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 46.33, 'feels_like': 42.39, 'temp_min': 39.99, 'temp_max': 53.6, 'pressure': 1023, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 3.36, 'deg': 350}, 'clouds': {'all': 1}, 'dt': 1604024674, 'sys': {'type': 1, 'id': 3986, 'country': 'US', 'sunrise': 1603975931, 'sunset': 1604014682}, 'timezone': -18000, 'id': 4535961, 'name': 'Enid', 'cod': 200}
# Processing Record 6 of Set 2 | lakes entrance
# {'coord': {'lon': 147.98, 'lat': -37.88}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 64.99, 'feels_like': 63.09, 'temp_min': 64.99, 'temp_max': 64.99, 'pressure': 1010, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 7, 'deg': 92, 'gust': 15.01}, 'clouds': {'all': 46}, 'dt': 1604024301, 'sys': {'type': 3, 'id': 2011895, 'country': 'AU', 'sunrise': 1603998191, 'sunset': 1604047207}, 'timezone': 39600, 'id': 2160735, 'name': 'Lakes Entrance', 'cod': 200}
# Processing Record 7 of Set 2 | kanniyakumari
# {'coord': {'lon': 77.57, 'lat': 8.08}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.31, 'feels_like': 86.23, 'temp_min': 80.31, 'temp_max': 80.31, 'pressure': 1012, 'humidity': 75, 'sea_level': 1012, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 4.56, 'deg': 15}, 'clouds': {'all': 47}, 'dt': 1604024707, 'sys': {'country': 'IN', 'sunrise': 1604018271, 'sunset': 1604060923}, 'timezone': 19800, 'id': 1268008, 'name': 'Kanniyākumāri', 'cod': 200}
# Processing Record 8 of Set 2 | vila velha
# {'coord': {'lon': -40.29, 'lat': -20.33}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 78.91, 'feels_like': 81.86, 'temp_min': 78.8, 'temp_max': 79, 'pressure': 1013, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 11.41, 'deg': 10}, 'clouds': {'all': 75}, 'dt': 1604024263, 'sys': {'type': 1, 'id': 8474, 'country': 'BR', 'sunrise': 1603958428, 'sunset': 1604004543}, 'timezone': -10800, 'id': 3445026, 'name': 'Vila Velha', 'cod': 200}
# Processing Record 9 of Set 2 | kodiak
# {'coord': {'lon': -152.41, 'lat': 57.79}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 41, 'feels_like': 34.81, 'temp_min': 41, 'temp_max': 41, 'pressure': 1012, 'humidity': 56}, 'visibility': 10000, 'wind': {'speed': 3.36, 'deg': 90}, 'clouds': {'all': 1}, 'dt': 1604024323, 'sys': {'type': 1, 'id': 7668, 'country': 'US', 'sunrise': 1603991859, 'sunset': 1604024927}, 'timezone': -28800, 'id': 5866583, 'name': 'Saint Paul Harbor', 'cod': 200}
# Processing Record 10 of Set 2 | hilo
# {'coord': {'lon': -155.09, 'lat': 19.73}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 76.21, 'feels_like': 80.62, 'temp_min': 72, 'temp_max': 80.6, 'pressure': 1010, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 4.7, 'deg': 30}, 'clouds': {'all': 90}, 'dt': 1604024279, 'sys': {'type': 1, 'id': 7881, 'country': 'US', 'sunrise': 1603988425, 'sunset': 1604029647}, 'timezone': -36000, 'id': 5855927, 'name': 'Hilo', 'cod': 200}
# Processing Record 11 of Set 2 | klaksvik
# {'coord': {'lon': -6.59, 'lat': 62.23}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 48.2, 'feels_like': 29.19, 'temp_min': 48.2, 'temp_max': 48.2, 'pressure': 987, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 32.21, 'deg': 100}, 'clouds': {'all': 100}, 'dt': 1604024299, 'sys': {'type': 1, 'id': 1596, 'country': 'FO', 'sunrise': 1604044446, 'sunset': 1604075144}, 'timezone': 0, 'id': 2618795, 'name': 'Klaksvík', 'cod': 200}
# Processing Record 12 of Set 2 | georgetown
# {'coord': {'lon': 100.34, 'lat': 5.41}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 84.11, 'feels_like': 92.32, 'temp_min': 84, 'temp_max': 84.2, 'pressure': 1011, 'humidity': 79}, 'visibility': 8000, 'wind': {'speed': 5.82, 'deg': 30}, 'clouds': {'all': 20}, 'dt': 1604024282, 'sys': {'type': 1, 'id': 9438, 'country': 'MY', 'sunrise': 1604012647, 'sunset': 1604055618}, 'timezone': 28800, 'id': 1735106, 'name': 'George Town', 'cod': 200}
# Processing Record 13 of Set 2 | hobart
# {'coord': {'lon': 147.33, 'lat': -42.88}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 61.27, 'feels_like': 51.71, 'temp_min': 59, 'temp_max': 66, 'pressure': 1013, 'humidity': 67}, 'visibility': 10000, 'wind': {'speed': 17.22, 'deg': 150}, 'clouds': {'all': 40}, 'dt': 1604024103, 'sys': {'type': 1, 'id': 9545, 'country': 'AU', 'sunrise': 1603997804, 'sunset': 1604047906}, 'timezone': 39600, 'id': 2163355, 'name': 'Hobart', 'cod': 200}
# Processing Record 14 of Set 2 | caravelas
# {'coord': {'lon': -39.25, 'lat': -17.71}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 76.46, 'feels_like': 79.3, 'temp_min': 76.46, 'temp_max': 76.46, 'pressure': 1014, 'humidity': 84, 'sea_level': 1014, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 9.66, 'deg': 35}, 'clouds': {'all': 100}, 'dt': 1604024354, 'sys': {'country': 'BR', 'sunrise': 1603958353, 'sunset': 1604004118}, 'timezone': -10800, 'id': 3466980, 'name': 'Caravelas', 'cod': 200}
# Processing Record 15 of Set 2 | lata
# {'coord': {'lon': -8.33, 'lat': 40.16}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 52.12, 'feels_like': 50.92, 'temp_min': 48.2, 'temp_max': 55.99, 'pressure': 1025, 'humidity': 100}, 'visibility': 8000, 'wind': {'speed': 3.36, 'deg': 150}, 'clouds': {'all': 0}, 'dt': 1604024368, 'sys': {'type': 1, 'id': 6896, 'country': 'PT', 'sunrise': 1604041239, 'sunset': 1604079186}, 'timezone': 0, 'id': 2738381, 'name': 'Lata', 'cod': 200}
# Processing Record 16 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 2 | jiaozuo
# {'coord': {'lon': 113.23, 'lat': 35.24}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 60.58, 'feels_like': 53.1, 'temp_min': 60.58, 'temp_max': 60.58, 'pressure': 1027, 'humidity': 36, 'sea_level': 1027, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 7.34, 'deg': 88}, 'clouds': {'all': 0}, 'dt': 1604024709, 'sys': {'country': 'CN', 'sunrise': 1604011587, 'sunset': 1604050491}, 'timezone': 28800, 'id': 1805987, 'name': 'Jiaozuo', 'cod': 200}
# Processing Record 18 of Set 2 | port alfred
# {'coord': {'lon': 26.89, 'lat': -33.59}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 60.62, 'feels_like': 52.56, 'temp_min': 60.62, 'temp_max': 60.62, 'pressure': 1026, 'humidity': 67, 'sea_level': 1026, 'grnd_level': 1024}, 'visibility': 10000, 'wind': {'speed': 14.27, 'deg': 231}, 'clouds': {'all': 100}, 'dt': 1604024288, 'sys': {'country': 'ZA', 'sunrise': 1604027639, 'sunset': 1604075881}, 'timezone': 7200, 'id': 964432, 'name': 'Port Alfred', 'cod': 200}
# Processing Record 19 of Set 2 | nikolsk
# {'coord': {'lon': 46.07, 'lat': 53.72}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 37.06, 'feels_like': 28.42, 'temp_min': 37.06, 'temp_max': 37.06, 'pressure': 1024, 'humidity': 81, 'sea_level': 1024, 'grnd_level': 996}, 'visibility': 10000, 'wind': {'speed': 8.93, 'deg': 147}, 'clouds': {'all': 99}, 'dt': 1604024709, 'sys': {'country': 'RU', 'sunrise': 1604029914, 'sunset': 1604064400}, 'timezone': 10800, 'id': 521776, 'name': "Nikol'sk", 'cod': 200}
# Processing Record 20 of Set 2 | tessaoua
# {'coord': {'lon': 7.99, 'lat': 13.76}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 80.4, 'feels_like': 71.4, 'temp_min': 80.4, 'temp_max': 80.4, 'pressure': 1011, 'humidity': 18, 'sea_level': 1011, 'grnd_level': 966}, 'visibility': 10000, 'wind': {'speed': 9.91, 'deg': 59}, 'clouds': {'all': 0}, 'dt': 1604024709, 'sys': {'country': 'NE', 'sunrise': 1604035319, 'sunset': 1604077272}, 'timezone': 3600, 'id': 2438823, 'name': 'Tessaoua', 'cod': 200}
# Processing Record 21 of Set 2 | faya
# {'coord': {'lon': 42.45, 'lat': 18.39}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 54.5, 'feels_like': 49.23, 'temp_min': 53.6, 'temp_max': 55.4, 'pressure': 1025, 'humidity': 40}, 'visibility': 10000, 'wind': {'speed': 2.68, 'deg': 53}, 'clouds': {'all': 0}, 'dt': 1604024388, 'sys': {'type': 1, 'id': 7396, 'country': 'SA', 'sunrise': 1604027341, 'sunset': 1604068711}, 'timezone': 10800, 'id': 110690, 'name': 'Faya', 'cod': 200}
# Processing Record 22 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 2 | babati
# {'coord': {'lon': 35.75, 'lat': -4.22}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 59.43, 'feels_like': 59.77, 'temp_min': 59.43, 'temp_max': 59.43, 'pressure': 1015, 'humidity': 89, 'sea_level': 1015, 'grnd_level': 867}, 'visibility': 10000, 'wind': {'speed': 2.82, 'deg': 115}, 'clouds': {'all': 81}, 'dt': 1604024710, 'sys': {'country': 'TZ', 'sunrise': 1604027577, 'sunset': 1604071691}, 'timezone': 10800, 'id': 161312, 'name': 'Babati', 'cod': 200}
# Processing Record 24 of Set 2 | tautira
# {'coord': {'lon': -149.15, 'lat': -17.73}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 82.4, 'feels_like': 84.85, 'temp_min': 82.4, 'temp_max': 82.4, 'pressure': 1012, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 13.87, 'deg': 50}, 'clouds': {'all': 40}, 'dt': 1604024710, 'sys': {'type': 1, 'id': 7318, 'country': 'PF', 'sunrise': 1603984719, 'sunset': 1604030503}, 'timezone': -36000, 'id': 4033557, 'name': 'Tautira', 'cod': 200}
# Processing Record 25 of Set 2 | pisco
# {'coord': {'lon': -76.22, 'lat': -13.7}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 62.78, 'feels_like': 54.09, 'temp_min': 62.6, 'temp_max': 63, 'pressure': 1014, 'humidity': 82}, 'visibility': 10000, 'wind': {'speed': 19.46, 'deg': 220}, 'clouds': {'all': 0}, 'dt': 1604024276, 'sys': {'type': 1, 'id': 8691, 'country': 'PE', 'sunrise': 1603967481, 'sunset': 1604012735}, 'timezone': -18000, 'id': 3932145, 'name': 'Pisco', 'cod': 200}
# Processing Record 26 of Set 2 | albany
# {'coord': {'lon': -73.97, 'lat': 42.6}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 40.95, 'feels_like': 32.29, 'temp_min': 39.99, 'temp_max': 42.01, 'pressure': 1005, 'humidity': 90}, 'visibility': 10000, 'wind': {'speed': 10.85, 'deg': 23}, 'rain': {'1h': 0.4}, 'clouds': {'all': 100}, 'dt': 1604024161, 'sys': {'type': 3, 'id': 19530, 'country': 'US', 'sunrise': 1603970784, 'sunset': 1604008352}, 'timezone': -14400, 'id': 5106841, 'name': 'Albany', 'cod': 200}
# Processing Record 27 of Set 2 | lorengau
# {'coord': {'lon': 147.27, 'lat': -2.02}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 84.15, 'feels_like': 89.19, 'temp_min': 84.15, 'temp_max': 84.15, 'pressure': 1008, 'humidity': 74, 'sea_level': 1008, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 9.37, 'deg': 206}, 'rain': {'1h': 1.14}, 'clouds': {'all': 100}, 'dt': 1604024711, 'sys': {'country': 'PG', 'sunrise': 1604000945, 'sunset': 1604044794}, 'timezone': 36000, 'id': 2092164, 'name': 'Lorengau', 'cod': 200}
# Processing Record 28 of Set 2 | ca mau
# {'coord': {'lon': 105.15, 'lat': 9.18}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 86.45, 'feels_like': 95.22, 'temp_min': 86.45, 'temp_max': 86.45, 'pressure': 1012, 'humidity': 68, 'sea_level': 1012, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 2.42, 'deg': 170}, 'clouds': {'all': 0}, 'dt': 1604024711, 'sys': {'country': 'VN', 'sunrise': 1604011717, 'sunset': 1604054239}, 'timezone': 25200, 'id': 1586443, 'name': 'Ca Mau', 'cod': 200}
# Processing Record 29 of Set 2 | catamarca
# {'coord': {'lon': -65.79, 'lat': -28.47}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 53.01, 'feels_like': 44.94, 'temp_min': 53.01, 'temp_max': 53.01, 'pressure': 1023, 'humidity': 50}, 'visibility': 10000, 'wind': {'speed': 8.77, 'deg': 45}, 'clouds': {'all': 36}, 'dt': 1604024711, 'sys': {'type': 3, 'id': 2004347, 'country': 'AR', 'sunrise': 1603963952, 'sunset': 1604011258}, 'timezone': -10800, 'id': 3837702, 'name': 'San Fernando del Valle de Catamarca', 'cod': 200}
# Processing Record 30 of Set 2 | tokur
# {'coord': {'lon': 132.9, 'lat': 53.13}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 28.74, 'feels_like': 21.69, 'temp_min': 28.74, 'temp_max': 28.74, 'pressure': 1024, 'humidity': 93, 'sea_level': 1024, 'grnd_level': 936}, 'visibility': 10000, 'wind': {'speed': 4.99, 'deg': 226}, 'clouds': {'all': 100}, 'dt': 1604024362, 'sys': {'country': 'RU', 'sunrise': 1604008949, 'sunset': 1604043688}, 'timezone': 32400, 'id': 2015217, 'name': 'Tokur', 'cod': 200}
# Processing Record 31 of Set 2 | taoudenni
# {'coord': {'lon': -3.98, 'lat': 22.68}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 75.25, 'feels_like': 63.18, 'temp_min': 75.25, 'temp_max': 75.25, 'pressure': 1016, 'humidity': 19, 'sea_level': 1016, 'grnd_level': 999}, 'visibility': 10000, 'wind': {'speed': 14.63, 'deg': 53}, 'clouds': {'all': 0}, 'dt': 1604024403, 'sys': {'country': 'ML', 'sunrise': 1604038773, 'sunset': 1604079564}, 'timezone': 0, 'id': 2450173, 'name': 'Taoudenni', 'cod': 200}
# Processing Record 32 of Set 2 | severo-kurilsk
# {'coord': {'lon': 156.12, 'lat': 50.68}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 44.1, 'feels_like': 34.54, 'temp_min': 44.1, 'temp_max': 44.1, 'pressure': 1023, 'humidity': 80, 'sea_level': 1023, 'grnd_level': 1022}, 'visibility': 10000, 'wind': {'speed': 12.46, 'deg': 107}, 'clouds': {'all': 48}, 'dt': 1604024383, 'sys': {'country': 'RU', 'sunrise': 1604002991, 'sunset': 1604038500}, 'timezone': 39600, 'id': 2121385, 'name': "Severo-Kuril'sk", 'cod': 200}
# Processing Record 33 of Set 2 | lagoa
# {'coord': {'lon': -27.98, 'lat': 39.05}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 67.24, 'feels_like': 66.13, 'temp_min': 67.24, 'temp_max': 67.24, 'pressure': 1016, 'humidity': 90, 'sea_level': 1016, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 10.78, 'deg': 272}, 'clouds': {'all': 100}, 'dt': 1604024346, 'sys': {'country': 'PT', 'sunrise': 1604045850, 'sunset': 1604084007}, 'timezone': -3600, 'id': 3372964, 'name': 'Lagoa', 'cod': 200}
# Processing Record 34 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 35 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 2 | saint george
# {'coord': {'lon': -113.58, 'lat': 37.1}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 62.6, 'feels_like': 55.45, 'temp_min': 62.6, 'temp_max': 62.6, 'pressure': 1020, 'humidity': 17}, 'visibility': 10000, 'wind': {'speed': 3.36, 'deg': 170}, 'clouds': {'all': 1}, 'dt': 1604024202, 'sys': {'type': 1, 'id': 5832, 'country': 'US', 'sunrise': 1603979764, 'sunset': 1604018385}, 'timezone': -21600, 'id': 5546220, 'name': 'Saint George', 'cod': 200}
# Processing Record 37 of Set 2 | hambantota
# {'coord': {'lon': 81.12, 'lat': 6.12}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 80.2, 'feels_like': 85.93, 'temp_min': 80.2, 'temp_max': 80.2, 'pressure': 1011, 'humidity': 75, 'sea_level': 1011, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 4.81, 'deg': 286}, 'clouds': {'all': 100}, 'dt': 1604024713, 'sys': {'country': 'LK', 'sunrise': 1604017302, 'sunset': 1604060188}, 'timezone': 19800, 'id': 1244926, 'name': 'Hambantota', 'cod': 200}
# Processing Record 38 of Set 2 | vostok
# {'coord': {'lon': 135.88, 'lat': 46.49}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 32.68, 'feels_like': 27.43, 'temp_min': 32.68, 'temp_max': 32.68, 'pressure': 1025, 'humidity': 100, 'sea_level': 1025, 'grnd_level': 941}, 'visibility': 4310, 'wind': {'speed': 3.15, 'deg': 301}, 'clouds': {'all': 100}, 'dt': 1604024318, 'sys': {'country': 'RU', 'sunrise': 1604007296, 'sunset': 1604043911}, 'timezone': 36000, 'id': 2013279, 'name': 'Vostok', 'cod': 200}
# Processing Record 39 of Set 2 | bethel
# {'coord': {'lon': -73.41, 'lat': 41.37}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 43.59, 'feels_like': 35.91, 'temp_min': 43, 'temp_max': 44.6, 'pressure': 1003, 'humidity': 93}, 'visibility': 6437, 'wind': {'speed': 10.29, 'deg': 40}, 'clouds': {'all': 90}, 'dt': 1604024330, 'sys': {'type': 1, 'id': 3888, 'country': 'US', 'sunrise': 1603970522, 'sunset': 1604008345}, 'timezone': -14400, 'id': 5282297, 'name': 'Bethel', 'cod': 200}
# Processing Record 40 of Set 2 | yomitan
# City not found. Skipping...
# Processing Record 41 of Set 2 | powell river
# ...
# Processing Record 34 of Set 12 | eyrarbakki
# {'coord': {'lon': -21.15, 'lat': 63.86}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 39.96, 'feels_like': 28.92, 'temp_min': 39, 'temp_max': 41, 'pressure': 982, 'humidity': 80}, 'visibility': 10000, 'wind': {'speed': 13.87, 'deg': 80}, 'clouds': {'all': 75}, 'dt': 1604024813, 'sys': {'type': 1, 'id': 91, 'country': 'IS', 'sunrise': 1604048451, 'sunset': 1604078128}, 'timezone': 0, 'id': 3413604, 'name': 'Eyrarbakki', 'cod': 200}
# Processing Record 35 of Set 12 | gushikawa
# {'coord': {'lon': 127.87, 'lat': 26.35}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 77.52, 'feels_like': 72.27, 'temp_min': 77, 'temp_max': 78.8, 'pressure': 1018, 'humidity': 61}, 'visibility': 10000, 'wind': {'speed': 17.22, 'deg': 10}, 'clouds': {'all': 75}, 'dt': 1604024813, 'sys': {'type': 1, 'id': 8138, 'country': 'JP', 'sunrise': 1604007374, 'sunset': 1604047677}, 'timezone': 32400, 'id': 1863495, 'name': 'Gushikawa', 'cod': 200}
# Processing Record 36 of Set 12 | fort abbas
# {'coord': {'lon': 72.85, 'lat': 29.19}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 69.69, 'feels_like': 64.99, 'temp_min': 69.69, 'temp_max': 69.69, 'pressure': 1016, 'humidity': 23, 'sea_level': 1016, 'grnd_level': 999}, 'visibility': 10000, 'wind': {'speed': 1.54, 'deg': 331}, 'clouds': {'all': 0}, 'dt': 1604024814, 'sys': {'country': 'PK', 'sunrise': 1604020795, 'sunset': 1604060665}, 'timezone': 18000, 'id': 1179223, 'name': 'Fort Abbas', 'cod': 200}
# Processing Record 37 of Set 12 | bartica
# {'coord': {'lon': -58.62, 'lat': 6.4}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 77, 'feels_like': 87.3, 'temp_min': 77, 'temp_max': 77, 'pressure': 1010, 'humidity': 100}, 'visibility': 10000, 'wind': {'speed': 2.24, 'deg': 0}, 'clouds': {'all': 20}, 'dt': 1604024814, 'sys': {'type': 1, 'id': 8767, 'country': 'GY', 'sunrise': 1603964453, 'sunset': 1604007316}, 'timezone': -14400, 'id': 3379507, 'name': 'Bartica', 'cod': 200}
# Processing Record 38 of Set 12 | bontang
# {'coord': {'lon': 117.5, 'lat': 0.13}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 83.66, 'feels_like': 87.96, 'temp_min': 83.66, 'temp_max': 83.66, 'pressure': 1011, 'humidity': 67, 'sea_level': 1011, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 7.31, 'deg': 80}, 'clouds': {'all': 59}, 'dt': 1604024814, 'sys': {'country': 'ID', 'sunrise': 1604008217, 'sunset': 1604051812}, 'timezone': 28800, 'id': 1648186, 'name': 'Bontang', 'cod': 200}
# Processing Record 39 of Set 12 | sinegorye
# {'coord': {'lon': 150.48, 'lat': 62.08}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 15.82, 'feels_like': 9.57, 'temp_min': 15.82, 'temp_max': 15.82, 'pressure': 1024, 'humidity': 92, 'sea_level': 1024, 'grnd_level': 962}, 'visibility': 4929, 'wind': {'speed': 1.32, 'deg': 28}, 'clouds': {'all': 100}, 'dt': 1604024814, 'sys': {'country': 'RU', 'sunrise': 1604006632, 'sunset': 1604037567}, 'timezone': 39600, 'id': 2121197, 'name': "Sinegor'ye", 'cod': 200}
# Processing Record 40 of Set 12 | saldanha
# {'coord': {'lon': 17.94, 'lat': -33.01}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 44.6, 'feels_like': 39.22, 'temp_min': 44.6, 'temp_max': 44.6, 'pressure': 1025, 'humidity': 75}, 'visibility': 10000, 'wind': {'speed': 4.7, 'deg': 180}, 'clouds': {'all': 0}, 'dt': 1604024274, 'sys': {'type': 1, 'id': 1943, 'country': 'ZA', 'sunrise': 1604029837, 'sunset': 1604077979}, 'timezone': 7200, 'id': 3361934, 'name': 'Saldanha', 'cod': 200}
# Processing Record 41 of Set 12 | nichinan
# {'coord': {'lon': 131.37, 'lat': 31.6}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 69.8, 'feels_like': 59.94, 'temp_min': 69.8, 'temp_max': 69.8, 'pressure': 1018, 'humidity': 52}, 'visibility': 10000, 'wind': {'speed': 18.34, 'deg': 20}, 'clouds': {'all': 40}, 'dt': 1604024815, 'sys': {'type': 1, 'id': 8001, 'country': 'JP', 'sunrise': 1604006929, 'sunset': 1604046442}, 'timezone': 32400, 'id': 1855476, 'name': 'Nichinan', 'cod': 200}
# Processing Record 42 of Set 12 | baykit
# {'coord': {'lon': 96.37, 'lat': 61.67}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 11.14, 'feels_like': 3.94, 'temp_min': 11.14, 'temp_max': 11.14, 'pressure': 1020, 'humidity': 92, 'sea_level': 1020, 'grnd_level': 1000}, 'visibility': 3632, 'wind': {'speed': 2.44, 'deg': 303}, 'clouds': {'all': 96}, 'dt': 1604024321, 'sys': {'country': 'RU', 'sunrise': 1604019530, 'sunset': 1604050641}, 'timezone': 25200, 'id': 1510689, 'name': 'Baykit', 'cod': 200}
# Processing Record 43 of Set 12 | dalian
# {'coord': {'lon': 121.6, 'lat': 38.91}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 60.8, 'feels_like': 57.83, 'temp_min': 60.8, 'temp_max': 60.8, 'pressure': 1028, 'humidity': 51}, 'visibility': 6000, 'wind': {'speed': 2.24, 'deg': 0}, 'clouds': {'all': 0}, 'dt': 1604024815, 'sys': {'type': 1, 'id': 9679, 'country': 'CN', 'sunrise': 1604009910, 'sunset': 1604048151}, 'timezone': 28800, 'id': 1814087, 'name': 'Dalian', 'cod': 200}
# Processing Record 44 of Set 12 | lanzhou
# {'coord': {'lon': 103.79, 'lat': 36.06}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 41, 'feels_like': 36.68, 'temp_min': 41, 'temp_max': 41, 'pressure': 1025, 'humidity': 80}, 'visibility': 7000, 'wind': {'speed': 2.24, 'deg': 0}, 'clouds': {'all': 40}, 'dt': 1604024815, 'sys': {'type': 1, 'id': 9639, 'country': 'CN', 'sunrise': 1604013926, 'sunset': 1604052683}, 'timezone': 28800, 'id': 1804430, 'name': 'Lanzhou', 'cod': 200}
# Processing Record 45 of Set 12 | kalmar
# {'coord': {'lon': 16.36, 'lat': 56.66}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 47.17, 'feels_like': 40.91, 'temp_min': 46.4, 'temp_max': 48, 'pressure': 1010, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 9.17, 'deg': 280}, 'clouds': {'all': 97}, 'dt': 1604024816, 'sys': {'type': 1, 'id': 1757, 'country': 'SE', 'sunrise': 1604037595, 'sunset': 1604070979}, 'timezone': 3600, 'id': 2702261, 'name': 'Kalmar', 'cod': 200}
# Processing Record 46 of Set 12 | gazli
# {'coord': {'lon': 63.45, 'lat': 40.13}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 36.86, 'feels_like': 25.11, 'temp_min': 36.86, 'temp_max': 36.86, 'pressure': 1028, 'humidity': 71, 'sea_level': 1028, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 13.65, 'deg': 63}, 'clouds': {'all': 0}, 'dt': 1604024816, 'sys': {'country': 'UZ', 'sunrise': 1604023995, 'sunset': 1604061976}, 'timezone': 18000, 'id': 1513990, 'name': 'Gazli', 'cod': 200}
# Processing Record 47 of Set 12 | sao felix do xingu
# {'coord': {'lon': -51.99, 'lat': -6.64}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 76.03, 'feels_like': 82.71, 'temp_min': 76.03, 'temp_max': 76.03, 'pressure': 1008, 'humidity': 84, 'sea_level': 1008, 'grnd_level': 986}, 'visibility': 10000, 'wind': {'speed': 2.44, 'deg': 156}, 'rain': {'1h': 0.68}, 'clouds': {'all': 68}, 'dt': 1604024707, 'sys': {'country': 'BR', 'sunrise': 1603962098, 'sunset': 1604006488}, 'timezone': -10800, 'id': 3388847, 'name': 'São Félix do Xingu', 'cod': 200}
# Processing Record 48 of Set 12 | beyneu
# {'coord': {'lon': 55.2, 'lat': 45.32}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 41.65, 'feels_like': 28.6, 'temp_min': 41.65, 'temp_max': 41.65, 'pressure': 1029, 'humidity': 62, 'sea_level': 1029, 'grnd_level': 1029}, 'visibility': 10000, 'wind': {'speed': 16.24, 'deg': 122}, 'clouds': {'all': 73}, 'dt': 1604024395, 'sys': {'country': 'KZ', 'sunrise': 1604026537, 'sunset': 1604063394}, 'timezone': 18000, 'id': 610298, 'name': 'Beyneu', 'cod': 200}
# Processing Record 49 of Set 12 | lima
# {'coord': {'lon': -77.03, 'lat': -12.04}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 62.29, 'feels_like': 56.61, 'temp_min': 62.01, 'temp_max': 62.6, 'pressure': 1014, 'humidity': 82}, 'visibility': 10000, 'wind': {'speed': 13.87, 'deg': 160}, 'clouds': {'all': 40}, 'dt': 1604024400, 'sys': {'type': 1, 'id': 8682, 'country': 'PE', 'sunrise': 1603967779, 'sunset': 1604012826}, 'timezone': -18000, 'id': 3936456, 'name': 'Lima', 'cod': 200}
# Processing Record 50 of Set 12 | bolama
# {'coord': {'lon': -15.47, 'lat': 11.58}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 82.17, 'feels_like': 86.61, 'temp_min': 82.17, 'temp_max': 82.17, 'pressure': 1010, 'humidity': 69, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 6.53, 'deg': 295}, 'clouds': {'all': 0}, 'dt': 1604024817, 'sys': {'country': 'GW', 'sunrise': 1604040816, 'sunset': 1604083036}, 'timezone': 0, 'id': 2374688, 'name': 'Bolama', 'cod': 200}
# Processing Record 1 of Set 13 | bilibino
# {'coord': {'lon': 166.44, 'lat': 68.05}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 3.96, 'feels_like': -3.19, 'temp_min': 3.96, 'temp_max': 3.96, 'pressure': 1025, 'humidity': 82, 'sea_level': 1025, 'grnd_level': 988}, 'visibility': 10000, 'wind': {'speed': 1.48, 'deg': 72}, 'clouds': {'all': 85}, 'dt': 1604024817, 'sys': {'country': 'RU', 'sunrise': 1604004984, 'sunset': 1604031554}, 'timezone': 43200, 'id': 2126682, 'name': 'Bilibino', 'cod': 200}
# Processing Record 2 of Set 13 | dwarka
# {'coord': {'lon': 68.97, 'lat': 22.24}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 79.83, 'feels_like': 79.72, 'temp_min': 79.83, 'temp_max': 79.83, 'pressure': 1013, 'humidity': 60, 'sea_level': 1013, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 9.33, 'deg': 14}, 'clouds': {'all': 0}, 'dt': 1604024817, 'sys': {'country': 'IN', 'sunrise': 1604021229, 'sunset': 1604062093}, 'timezone': 19800, 'id': 1272140, 'name': 'Dwārka', 'cod': 200}
# Processing Record 3 of Set 13 | atasu
# {'coord': {'lon': 71.64, 'lat': 48.68}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 28.44, 'feels_like': 19.33, 'temp_min': 28.44, 'temp_max': 28.44, 'pressure': 1038, 'humidity': 85, 'sea_level': 1038, 'grnd_level': 977}, 'visibility': 10000, 'wind': {'speed': 8.12, 'deg': 237}, 'clouds': {'all': 0}, 'dt': 1604024817, 'sys': {'country': 'KZ', 'sunrise': 1604023010, 'sunset': 1604059030}, 'timezone': 21600, 'id': 1526041, 'name': 'Atasū', 'cod': 200}
# Processing Record 4 of Set 13 | eskisehir
# {'coord': {'lon': 30.52, 'lat': 39.78}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 46.4, 'feels_like': 43.86, 'temp_min': 46.4, 'temp_max': 46.4, 'pressure': 1018, 'humidity': 93}, 'visibility': 7000, 'wind': {'speed': 2.21, 'deg': 115}, 'clouds': {'all': 31}, 'dt': 1604024818, 'sys': {'type': 1, 'id': 6988, 'country': 'TR', 'sunrise': 1604031870, 'sunset': 1604069907}, 'timezone': 10800, 'id': 315202, 'name': 'Eskişehir', 'cod': 200}
# Processing Record 5 of Set 13 | ust-nera
# {'coord': {'lon': 143.2, 'lat': 64.57}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 10.72, 'feels_like': 3.24, 'temp_min': 10.72, 'temp_max': 10.72, 'pressure': 1024, 'humidity': 88, 'sea_level': 1024, 'grnd_level': 962}, 'visibility': 229, 'wind': {'speed': 2.8, 'deg': 36}, 'snow': {'1h': 0.16}, 'clouds': {'all': 100}, 'dt': 1604024818, 'sys': {'country': 'RU', 'sunrise': 1604009158, 'sunset': 1604038534}, 'timezone': 36000, 'id': 2120048, 'name': 'Ust-Nera', 'cod': 200}
# Processing Record 6 of Set 13 | ust-maya
# {'coord': {'lon': 134.53, 'lat': 60.42}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 6.04, 'feels_like': -1.44, 'temp_min': 6.04, 'temp_max': 6.04, 'pressure': 1028, 'humidity': 91, 'sea_level': 1028, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 2.42, 'deg': 75}, 'clouds': {'all': 55}, 'dt': 1604024818, 'sys': {'country': 'RU', 'sunrise': 1604010026, 'sunset': 1604041828}, 'timezone': 32400, 'id': 2013918, 'name': 'Ust-Maya', 'cod': 200}
# Processing Record 7 of Set 13 | olafsvik
# {'coord': {'lon': -23.71, 'lat': 64.89}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 42.06, 'feels_like': 30.45, 'temp_min': 42.06, 'temp_max': 42.06, 'pressure': 981, 'humidity': 86, 'sea_level': 981, 'grnd_level': 978}, 'visibility': 10000, 'wind': {'speed': 16.06, 'deg': 101}, 'rain': {'1h': 0.5056}, 'clouds': {'all': 100}, 'dt': 1604024818, 'sys': {'country': 'IS', 'sunrise': 1604049422, 'sunset': 1604078386}, 'timezone': 0, 'id': 3414079, 'name': 'Olafsvik', 'cod': 200}
# Processing Record 8 of Set 13 | parabel
# {'coord': {'lon': 81.48, 'lat': 58.7}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 19.02, 'feels_like': 12.63, 'temp_min': 19.02, 'temp_max': 19.02, 'pressure': 1015, 'humidity': 98, 'sea_level': 1015, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 2.24, 'deg': 232}, 'clouds': {'all': 47}, 'dt': 1604024613, 'sys': {'country': 'RU', 'sunrise': 1604022373, 'sunset': 1604054945}, 'timezone': 25200, 'id': 1495586, 'name': "Parabel'", 'cod': 200}
# Processing Record 9 of Set 13 | staszow
# {'coord': {'lon': 21.17, 'lat': 50.56}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 43.99, 'feels_like': 40.89, 'temp_min': 43, 'temp_max': 46, 'pressure': 1017, 'humidity': 90}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 224, 'gust': 5.01}, 'clouds': {'all': 0}, 'dt': 1604024819, 'sys': {'type': 3, 'id': 2011337, 'country': 'PL', 'sunrise': 1604035400, 'sunset': 1604070865}, 'timezone': 3600, 'id': 758252, 'name': 'Staszów', 'cod': 200}
# Processing Record 10 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 11 of Set 13 | celestun
# {'coord': {'lon': -90.4, 'lat': 20.87}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 79.14, 'feels_like': 78.17, 'temp_min': 79.14, 'temp_max': 79.14, 'pressure': 1014, 'humidity': 85, 'sea_level': 1014, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 19.3, 'deg': 24}, 'rain': {'1h': 0.27}, 'clouds': {'all': 98}, 'dt': 1604024819, 'sys': {'country': 'MX', 'sunrise': 1603972969, 'sunset': 1604014053}, 'timezone': -21600, 'id': 3531368, 'name': 'Celestún', 'cod': 200}
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 564

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Butaritari   3.07  172.79     82.04        75          72       11.52
# 1       Dudinka  69.41   86.18      8.24        92          90       12.44
# 2      Luderitz -26.65   15.16     56.39        74           0       27.83
# 3     Upernavik  72.79  -56.15     22.91        97         100        5.03
# 4       Rikitea -23.12 -134.97     75.56        73         100        6.73
# ..          ...    ...     ...       ...       ...         ...         ...
# 559    Ust-Maya  60.42  134.53      6.04        91          55        2.42
# 560    Olafsvik  64.89  -23.71     42.06        86         100       16.06
# 561     Parabel  58.70   81.48     19.02        98          47        2.24
# 562     Staszow  50.56   21.17     46.00        90           0        1.99
# 563    Celestun  20.87  -90.40     79.14        85          98       19.30
#
#     Country                 Date Current Description
# 0        KI  2020-10-30 02:15:15       broken clouds
# 1        RU  2020-10-30 02:24:56     overcast clouds
# 2        NA  2020-10-30 02:19:39           clear sky
# 3        GL  2020-10-30 02:18:55          light snow
# 4        PF  2020-10-30 02:17:50     overcast clouds
# ..      ...                  ...                 ...
# 559      RU  2020-10-30 02:26:58       broken clouds
# 560      IS  2020-10-30 02:26:58          light rain
# 561      RU  2020-10-30 02:23:33    scattered clouds
# 562      PL  2020-10-30 02:26:59           clear sky
# 563      MX  2020-10-30 02:26:59          light rain
#
# [564 rows x 10 columns]

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]

# %%
city_data_df
# Out:
#            City Country                 Date    Lat     Lng  Max Temp  \
# 0    Butaritari      KI  2020-10-30 02:15:15   3.07  172.79     82.04
# 1       Dudinka      RU  2020-10-30 02:24:56  69.41   86.18      8.24
# 2      Luderitz      NA  2020-10-30 02:19:39 -26.65   15.16     56.39
# 3     Upernavik      GL  2020-10-30 02:18:55  72.79  -56.15     22.91
# 4       Rikitea      PF  2020-10-30 02:17:50 -23.12 -134.97     75.56
# ..          ...     ...                  ...    ...     ...       ...
# 559    Ust-Maya      RU  2020-10-30 02:26:58  60.42  134.53      6.04
# 560    Olafsvik      IS  2020-10-30 02:26:58  64.89  -23.71     42.06
# 561     Parabel      RU  2020-10-30 02:23:33  58.70   81.48     19.02
# 562     Staszow      PL  2020-10-30 02:26:59  50.56   21.17     46.00
# 563    Celestun      MX  2020-10-30 02:26:59  20.87  -90.40     79.14
#
#      Humidity  Cloudiness  Wind Speed Current Description
# 0          75          72       11.52       broken clouds
# 1          92          90       12.44     overcast clouds
# 2          74           0       27.83           clear sky
# 3          97         100        5.03          light snow
# 4          73         100        6.73     overcast clouds
# ..        ...         ...         ...                 ...
# 559        91          55        2.42       broken clouds
# 560        86         100       16.06          light rain
# 561        98          47        2.24    scattered clouds
# 562        90           0        1.99           clear sky
# 563        85          98       19.30          light rain
#
# [564 rows x 10 columns]

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
